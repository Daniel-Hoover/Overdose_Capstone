# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
county_economy=pd.read_csv(r'C:\Users\Thund\NSS_Data_Analytics\Projects\Capstone\overdose\data\county_economic_data.csv')
county_economy
# Out:
#            geoid                   name  B19001001  B19001001, Error  \
# 0        01000US          United States  125736350            198714
# 1      04000US47              Tennessee    2713635              7405
# 2   05000US47001    Anderson County, TN      31275               606
# 3   05000US47003     Bedford County, TN      18469               369
# 4   05000US47005      Benton County, TN       6736               285
# ..           ...                    ...        ...               ...
# 92  05000US47181       Wayne County, TN       5744               219
# 93  05000US47183     Weakley County, TN      13129               290
# 94  05000US47185       White County, TN      10716               277
# 95  05000US47187  Williamson County, TN      88238               569
# 96  05000US47189      Wilson County, TN      55037               551
#
#     B19001002  B19001002, Error  B19001003  B19001003, Error  B19001004  \
# ...

# %%
#This is the data set of overdose across the country
od_counts_country=pd.read_csv(r'C:\Users\Thund\NSS_Data_Analytics\Projects\Capstone\overdose\data\VSRR_Provisional_Drug_Overdose_Death_Counts.csv')
od_counts_country=od_counts_country.drop(columns=['Footnote','Footnote Symbol'])
od_counts_country=
# Out:
#       State  Year      Month           Period  \
# 0        AK  2015      April  12 month-ending
# 1        AK  2015      April  12 month-ending
# 2        AK  2015      April  12 month-ending
# 3        AK  2015      April  12 month-ending
# 4        AK  2015      April  12 month-ending
# ...     ...   ...        ...              ...
# 63940    YC  2023  September  12 month-ending
# 63941    YC  2023  September  12 month-ending
# 63942    YC  2023  September  12 month-ending
# 63943    YC  2023  September  12 month-ending
# 63944    YC  2023  September  12 month-ending
#
#                                                Indicator  Data Value  \
# 0                           Percent with drugs specified  88.0952381
# 1          Psychostimulants with abuse potential (T43.6)         NaN
# 2                         Number of Drug Overdose Deaths         126
# 3                                      Methadone (T40.3)         NaN
# ...

# %%
#investigating TN's deaths for Jan. 2021 as a test
test=od_counts_country.loc[od_counts_country['Year']==2021]
test2=test.loc[test['Indicator']=='Number of Drug Overdose Deaths']
test3=test2.loc[test2['State']=='TN']
test4=test3.groupby('Month')['Data Value'].sum()
test4
# Out:
# Month
# April        3,512
# August       3,603
# December     3,861
# February     3,323
# January      3,215
# July         3,535
# June         3,508
# March        3,415
# May          3,485
# November     3,814
# October      3,749
# September    3,688
# Name: Data Value, dtype: object

# %%
# This is the county data for the whole country
od_counts_county=pd.read_csv(r'C:\Users\Thund\NSS_Data_Analytics\Projects\Capstone\overdose\data\VSRR_Provisional_County-Level_Drug_Overdose_Death_Counts.csv')
od_counts_county=od_counts_county.drop(columns=['Footnote', 'HistoricalDataCompletenessNote', 'Start Date', 'End Date'])

# %%
tn_counties=od_counts_county.loc[od_counts_county['ST_ABBREV']=='TN']
tn_counties
# Out:
#         Data as of  Year  Month ST_ABBREV STATE_NAME COUNTYNAME   FIPS  \
# 101976  01/07/2024  2020      6        TN  Tennessee   Anderson  47001
# 101977  01/07/2024  2020      1        TN  Tennessee   Anderson  47001
# 101978  01/07/2024  2021      1        TN  Tennessee   Anderson  47001
# 101979  01/07/2024  2020      7        TN  Tennessee   Anderson  47001
# 101980  01/07/2024  2022      9        TN  Tennessee   Anderson  47001
# ...            ...   ...    ...       ...        ...        ...    ...
# 105961  01/07/2024  2020      3        TN  Tennessee     Wilson  47189
# 105962  01/07/2024  2020      4        TN  Tennessee     Wilson  47189
# 105963  01/07/2024  2020      5        TN  Tennessee     Wilson  47189
# 105964  01/07/2024  2020      1        TN  Tennessee     Wilson  47189
# 105965  01/07/2024  2020      2        TN  Tennessee     Wilson  47189
#
#         STATEFIPS  COUNTYFIPS  CODE2013  Provisional Drug Overdose Deaths  \
# ...

# %%
#Investigating January 2021 for all of TN to see if it matches
test=tn_counties.loc[tn_counties['MonthEndingDate']=='01/31/2021']
test2=test.groupby('STATE_NAME')['Provisional Drug Overdose Deaths'].agg(sum)
test2
# Out:
# STATE_NAME
# Tennessee    2950.0
# Name: Provisional Drug Overdose Deaths, dtype: float64

# %%
#investigating Williamson county in 2021
test=tn_counties.loc[tn_counties['Year']==2021]
test2=test.loc[test['COUNTYNAME']=='Williamson']
test3=test2.groupby('COUNTYNAME')['Provisional Drug Overdose Deaths'].agg(sum)
test3
# Out:
# COUNTYNAME
# Williamson    436.0
# Name: Provisional Drug Overdose Deaths, dtype: float64

# %%
#reading in TN specific data from TN gov website.
tn_fatal=pd.read_excel(r'C:\Users\Thund\NSS_Data_Analytics\Projects\Capstone\overdose\data\fatal_tn.xlsx')
tn_fatal
# Out:
#        Year Geography GeographyType  \
# 0      2017  Anderson        County
# 1      2017  Anderson        County
# 2      2017  Anderson        County
# 3      2017  Anderson        County
# 4      2017  Anderson        County
# ...     ...       ...           ...
# 13635  2021    Wilson        County
# 13636  2021    Wilson        County
# 13637  2021    Wilson        County
# 13638  2021    Wilson        County
# 13639  2021    Wilson        County
#
#                                                Indicator  Value ValueType
# 0          Drug Overdose Deaths Involving All Stimulants   20.0     Count
# 1         Drug Overdose Deaths Involving Benzodiazepines   11.0     Count
# 2                 Drug Overdose Deaths Involving Cocaine    7.0     Count
# 3                Drug Overdose Deaths Involving Fentanyl   11.0     Count
# 4                  Drug Overdose Deaths Involving Heroin    7.0     Count
# ...                                                  ...    ...       ...
# ...

# %%
drug_deaths=tn_fatal[tn_fatal['Indicator']== 'All Drug Overdose Deaths']
drug_deaths
# Out:
#        Year   Geography GeographyType                 Indicator  Value  \
# 9      2017    Anderson        County  All Drug Overdose Deaths   47.0
# 20     2017    Anderson        County  All Drug Overdose Deaths   60.0
# 31     2017     Bedford        County  All Drug Overdose Deaths    5.0
# 42     2017     Bedford        County  All Drug Overdose Deaths    NaN
# 53     2017      Benton        County  All Drug Overdose Deaths    6.0
# ...     ...         ...           ...                       ...    ...
# 13594  2021       White        County  All Drug Overdose Deaths   55.0
# 13605  2021  Williamson        County  All Drug Overdose Deaths   41.0
# 13616  2021  Williamson        County  All Drug Overdose Deaths   17.0
# 13627  2021      Wilson        County  All Drug Overdose Deaths   63.0
# 13638  2021      Wilson        County  All Drug Overdose Deaths   44.0
#
#       ValueType
# 9         Count
# 20         Rate
# 31        Count
# 42         Rate
# 53        Count
# ...

# %%
#testing Williamson county in 2021 to see if matches
test=tn_fatal.loc[tn_fatal['Year']==2021]
test2=test.loc[test['Geography']=='Williamson']
test3=test2.groupby('Geography')['Value'].agg(sum)
test3
# Out:
# Geography
# Williamson    247.0
# Name: Value, dtype: float64

# %%
tn_nonfatal=pd.read_excel(r'C:\Users\Thund\NSS_Data_Analytics\Projects\Capstone\overdose\data\nonfatal_tn.xlsx')
tn_nonfatal
# Out:
#        Year Geography GeographyType  \
# 0      2017  Anderson        County
# 1      2017  Anderson        County
# 2      2017  Anderson        County
# 3      2017  Anderson        County
# 4      2017  Anderson        County
# ...     ...       ...           ...
# 14635  2021    Wilson        County
# 14636  2021    Wilson        County
# 14637  2021    Wilson        County
# 14638  2021    Wilson        County
# 14639  2021    Wilson        County
#
#                                                Indicator  Value ValueType  \
# 0      Inpatient Stays Involving Amphetamine Overdose...   11.0     Count
# 1      Outpatient Visits Involving Amphetamine Overdo...   10.0     Count
# 2             Inpatient Stays Involving Cocaine Overdose    4.0     Count
# 3           Outpatient Visits Involving Cocaine Overdose    1.0     Count
# 4              Inpatient Stays Involving Heroin Overdose    5.0     Count
# ...                                                  ...    ...       ...
# ...

# %%
prescribed_tn=pd.read_excel(r'C:\Users\Thund\NSS_Data_Analytics\Projects\Capstone\overdose\data\prescribe.xlsx')
prescribed_tn
# Out:
#        Year Geography GeographyType             Indicator  Value ValueType
# 0      2018  Anderson        County   All Benzodiazepines  43485     Count
# 1      2018  Anderson        County            Alprazolam  15416     Count
# 2      2018  Anderson        County            Clonazepam  10367     Count
# 3      2018  Anderson        County              Diazepam   4759     Count
# 4      2018  Anderson        County             Lorazepam   9099     Count
# ...     ...       ...           ...                   ...    ...       ...
# 14710  2022    Wilson        County             Lorazepam     53      Rate
# 14711  2022    Wilson        County  All Opioids for Pain    584      Rate
# 14712  2022    Wilson        County           Hydrocodone    240      Rate
# 14713  2022    Wilson        County             Oxycodone    201      Rate
# 14714  2022    Wilson        County              Tramadol     88      Rate
#
# [14715 rows x 6 columns]

# %%
od_demographs=pd.read_csv(r'C:\Users\Thund\NSS_Data_Analytics\Projects\Capstone\overdose\data\Drug_overdose_death_rates__by_drug_type__sex__age__race__and_Hispanic_origin__United_States.csv')
od_demographs
# Out:
#                       INDICATOR                                  PANEL  \
# 0     Drug overdose death rates               All drug overdose deaths
# 1     Drug overdose death rates               All drug overdose deaths
# 2     Drug overdose death rates               All drug overdose deaths
# 3     Drug overdose death rates               All drug overdose deaths
# 4     Drug overdose death rates               All drug overdose deaths
# ...                         ...                                    ...
# 6223  Drug overdose death rates  Drug overdose deaths involving heroin
# 6224  Drug overdose death rates  Drug overdose deaths involving heroin
# 6225  Drug overdose death rates  Drug overdose deaths involving heroin
# 6226  Drug overdose death rates  Drug overdose deaths involving heroin
# 6227  Drug overdose death rates  Drug overdose deaths involving heroin
#
#       PANEL_NUM                                               UNIT  UNIT_NUM  \
# ...

# %%
demo_totals=od_demographs.loc[od_demographs['PANEL']=='Drug overdose deaths involving any opioid']
demo_totals
# Out:
#                       INDICATOR                                      PANEL  \
# 987   Drug overdose death rates  Drug overdose deaths involving any opioid
# 988   Drug overdose death rates  Drug overdose deaths involving any opioid
# 989   Drug overdose death rates  Drug overdose deaths involving any opioid
# 990   Drug overdose death rates  Drug overdose deaths involving any opioid
# 991   Drug overdose death rates  Drug overdose deaths involving any opioid
# ...                         ...                                        ...
# 6019  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6020  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6021  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6022  Drug overdose death rates  Drug overdose deaths involving any opioid
# 6023  Drug overdose death rates  Drug overdose deaths involving any opioid
#
# ...

# %%
grouped=od_demographs.groupby('PANEL')['YEAR'].count()
grouped
# Out:
# PANEL
# All drug overdose deaths                                                         1038
# Drug overdose deaths involving any opioid                                        1038
# Drug overdose deaths involving heroin                                            1038
# Drug overdose deaths involving methadone                                         1038
# Drug overdose deaths involving natural and semisynthetic opioids                 1038
# Drug overdose deaths involving other synthetic opioids (other than methadone)    1038
# Name: YEAR, dtype: int64
